# %%
#if using colab install requirements.txt

# %%
import pandas as pd
# from google.colab import drive , files # if using colab uncomment this
from collections import Counter
from datasets import Dataset
from tensorflow.keras.preprocessing.sequence import pad_sequences
from transformers import AutoTokenizer, AutoModelForCausalLM , TrainingArguments , Trainer , pipeline
import torch # if cuda
import shutil
import os

# %%
file_path = 'df_all_cleans.csv'

# %%
# drive.mount('/content/drive') # if using colab uncomment this
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_all = pd.read_csv(file_path)

# %%
df_all.head()
# Out:
#    Unnamed: 0    id            poem  poet      cat  \
# 0           0  1119  رباعی شمارهٔ ۱  خیام  رباعیات
# 1           1  1120  رباعی شمارهٔ ۲  خیام  رباعیات
# 2           2  1121  رباعی شمارهٔ ۳  خیام  رباعیات
# 3           3  1122  رباعی شمارهٔ ۴  خیام  رباعیات
# 4           4  1123  رباعی شمارهٔ ۵  خیام  رباعیات
#
#                                                 text  \
# 0  برخیز بتا بیا ز بهر دل ما\nحل کن به جمال خویشت...
# 1  چون عهده نمی‌شود کسی فردا را\nحالی خوش دار این...
# 2  قرآن که مهین کلام خوانند آن را\nگهگاه نه بر دو...
# 3  گر می نخوری طعنه مزن مستان را\nبنیاد مکن تو حی...
# 4  هر چند که رنگ و بوی زیباست مرا\nچون لاله رخ و ...
#
#                                         text_cleaned  \
# 0  برخیز بتا بیا ز بهر دل ما\nحل کن به جمال خویشت...
# 1  چون عهده نمیشود کسی فردا را\nحالی خوش دار این ...
# 2  قرآن که مهین کلام خوانند آن را\nگهگاه نه بر دو...
# 3  گر می نخوری طعنه مزن مستان را\nبنیاد مکن تو حی...
# 4  هر چند که رنگ و بوی زیباست مرا\nچون لاله رخ و ...
#
#                                       text_formatted
# 0  <STYLE:ROBAEE> <START> برخیز بتا بیا ز بهر دل ...
# 1  <STYLE:ROBAEE> <START> چون عهده نمیشود کسی فرد...
# 2  <STYLE:ROBAEE> <START> قرآن که مهین کلام خوانن...
# 3  <STYLE:ROBAEE> <START> گر می نخوری طعنه مزن مس...
# 4  <STYLE:ROBAEE> <START> هر چند که رنگ و بوی زیب...

# %%
tokenized_poems = df_all["text_formatted"].apply(lambda x: x.strip().split())

# %%
SPECIAL_TOKENS = ['<PAD>', '<UNK>', '<START>', '<END>', '<LINE_BREAK>']

# %%
counter = Counter()
for tokens in tokenized_poems:
    counter.update(tokens)

min_freq = 2
vocab = [t for t, c in counter.items() if c >= min_freq and t not in SPECIAL_TOKENS]
vocab = SPECIAL_TOKENS + vocab

word2id = {w: i for i, w in enumerate(vocab)}
id2word = {i: w for w, i in word2id.items()}

# %%
def encode(tokens):
    return [word2id.get(t, word2id['<UNK>']) for t in tokens]

sequences = tokenized_poems.apply(encode)

# %%
max_len = max(sequences.apply(len))
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post', value=word2id['<PAD>'])

# %%
model_name = "HooshvareLab/gpt2-fa"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/808 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/875k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.75M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/14.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/104 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/485M [00:00<?, ?B/s]

# %%
dataset = Dataset.from_pandas(df_all[["text_formatted"]])

# %%
def tokenize_fn(example):
    encoding = tokenizer(
        example["text_formatted"],
        truncation=True,
        max_length=256,
        padding="max_length"
    )
    encoding["labels"] = encoding["input_ids"].copy()
    return encoding

# %%
tokenized_dataset = dataset.map(tokenize_fn, batched=True)
tokenized_dataset.set_format(
    type='torch', columns=['input_ids', 'attention_mask', 'labels']
)
# Out:
# Map:   0%|          | 0/66957 [00:00<?, ? examples/s]

# %%
training_args = TrainingArguments(
    output_dir="../gpt2-farsi-poetry",
    overwrite_output_dir=True,
    num_train_epochs=5,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    save_strategy="epoch",
    save_total_limit=2,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_dir="./logs",
    logging_steps=50,
    warmup_steps=100,
    lr_scheduler_type="linear",
    fp16=True,
    dataloader_num_workers=2,
    report_to="none",
    push_to_hub=False
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
)
# Out:
# <ipython-input-25-6f53e61b8a72>:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
trainer.save_model("./gpt2-farsi-poetry")
tokenizer.save_pretrained("./gpt2-farsi-poetry")
# Out:
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='10928' max='20925' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10928/20925 1:34:27 < 1:26:25, 1.93 it/s, Epoch 2.61/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>5.942500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.850000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.690700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.557100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.469800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.526900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.507700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.417300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>2.419100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>2.486300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>2.435500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>2.398400</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>2.384300</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>2.370100</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>2.345100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>2.287300</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>2.312700</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>2.368600</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>2.258700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.327100</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>2.255600</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>2.359200</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>2.308300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>2.281800</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>2.236500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>2.319600</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>2.301600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>2.286400</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>2.241500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.276400</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>2.183400</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>2.257100</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>2.196900</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>2.218700</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>2.249300</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>2.246300</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>2.222900</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>2.205300</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>2.198900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.198800</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>2.260000</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>2.206300</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>2.237300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>2.192200</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>2.168200</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>2.267500</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>2.221600</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>2.177700</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>2.203200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.163600</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>2.213400</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>2.181200</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>2.164100</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>2.224500</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>2.171200</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>2.146600</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>2.199400</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>2.146700</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>2.215900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.199800</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>2.087500</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>2.194600</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>2.082300</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>2.108600</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>2.171400</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>2.173400</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>2.166000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>2.102800</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>2.169300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.128000</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>2.206700</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>2.124200</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>2.165200</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>2.092900</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>2.131700</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>2.108900</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>2.124000</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>2.115000</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>2.126100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.126300</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>2.120500</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>2.134100</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>2.086800</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>2.084600</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>2.035900</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>2.074400</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>2.121900</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>1.995000</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>2.042300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.075100</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>2.081400</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>2.015300</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>2.048900</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>2.025700</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>2.047800</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>2.085900</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>2.050100</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>2.086300</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>2.025000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.028100</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>2.109300</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>2.030300</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>2.023300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>2.041700</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>2.070400</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>2.062900</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>2.117200</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>2.071800</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.030000</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>2.022800</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>2.037000</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>2.050600</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>2.051900</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>2.053500</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>2.025100</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>2.017800</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>2.030200</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>2.001600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.072900</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>2.028800</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#     <div>
#
#       <progress value='20925' max='20925' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20925/20925 3:02:05, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>5.942500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.850000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.690700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.557100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.469800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.526900</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.507700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.417300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>2.419100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>2.486300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>2.435500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>2.398400</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>2.384300</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>2.370100</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>2.345100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>2.287300</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>2.312700</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>2.368600</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>2.258700</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>2.327100</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>2.255600</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>2.359200</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>2.308300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>2.281800</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>2.236500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>2.319600</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>2.301600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>2.286400</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>2.241500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.276400</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>2.183400</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>2.257100</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>2.196900</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>2.218700</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>2.249300</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>2.246300</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>2.222900</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>2.205300</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>2.198900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.198800</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>2.260000</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>2.206300</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>2.237300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>2.192200</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>2.168200</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>2.267500</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>2.221600</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>2.177700</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>2.203200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.163600</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>2.213400</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>2.181200</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>2.164100</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>2.224500</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>2.171200</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>2.146600</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>2.199400</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>2.146700</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>2.215900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.199800</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>2.087500</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>2.194600</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>2.082300</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>2.108600</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>2.171400</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>2.173400</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>2.166000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>2.102800</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>2.169300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.128000</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>2.206700</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>2.124200</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>2.165200</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>2.092900</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>2.131700</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>2.108900</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>2.124000</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>2.115000</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>2.126100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.126300</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>2.120500</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>2.134100</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>2.086800</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>2.084600</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>2.035900</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>2.074400</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>2.121900</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>1.995000</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>2.042300</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.075100</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>2.081400</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>2.015300</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>2.048900</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>2.025700</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>2.047800</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>2.085900</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>2.050100</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>2.086300</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>2.025000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.028100</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>2.109300</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>2.030300</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>2.023300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>2.041700</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>2.070400</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>2.062900</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>2.117200</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>2.071800</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.030000</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>2.022800</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>2.037000</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>2.050600</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>2.051900</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>2.053500</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>2.025100</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>2.017800</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>2.030200</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>2.001600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.072900</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>2.028800</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>2.107900</td>
# ('./gpt2-farsi-poetry/tokenizer_config.json',
#  './gpt2-farsi-poetry/special_tokens_map.json',
#  './gpt2-farsi-poetry/vocab.json',
#  './gpt2-farsi-poetry/merges.txt',
#  './gpt2-farsi-poetry/added_tokens.json',
#  './gpt2-farsi-poetry/tokenizer.json')

# %%
folder_to_zip = "./gpt2-farsi-poetry"
output_zip_file = "gpt2-farsi-poetry.zip"

if os.path.exists(folder_to_zip):
    shutil.make_archive(output_zip_file.replace(".zip", ""), 'zip', folder_to_zip)
    print(f"Folder '{folder_to_zip}' has been zipped to '{output_zip_file}'")
else:
    print(f"Error: Folder '{folder_to_zip}' not found.")
# Out:
# Folder './gpt2-farsi-poetry' has been zipped to 'gpt2-farsi-poetry.zip'

# %%
# !du -sh ./gpt2-farsi-poetry
# Out:
# 3.1G	./gpt2-farsi-poetry
